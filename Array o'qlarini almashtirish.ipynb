# %%
import numpy as np

# %%
a = np.arange(6)
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a.reshape(3,2) #massiv shaklini o'zgartirish
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
a = np.arange(6).reshape(3,2)
a
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
a.T # a massivning Transpose ko'rinishi
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
a
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
a.swapaxes(1,0) # a massivni swaping axes usulida Transpose ko'rinishi
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
np.dot(a, a.T) # bir turdagi massivni boshqa turdagi massivga ko'paytirish
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])
