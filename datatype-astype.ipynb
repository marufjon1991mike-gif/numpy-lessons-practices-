# %%
import numpy as np

# %%
arr = np.array([1, 3.4, 2, 8])

# %%
arr
# Out:
# array([1. , 3.4, 2. , 8. ])

# %%
arr.dtype #massivning malumot turini korsatadi
# Out:
# dtype('float64')

# %%
arr2 = np.array([1, 2, 3, 4])

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
float_arr = arr2.astype(np.float64) #malumot turini o'zgartirish

# %%
float_arr.dtype
# Out:
# dtype('float64')
