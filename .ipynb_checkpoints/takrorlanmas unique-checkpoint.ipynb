# %%
import numpy as np

# %%
names = np.array(["Sarvar", "Abdurahmon", "Hasan", "Temur", "Sarvar", "Temur"])

# %%
np.unique(names) #takrorlanmas yoki faqat takrorlangan qiymatlarning bittasini qaytaradi
# Out:
# array(['Abdurahmon', 'Hasan', 'Sarvar', 'Temur'], dtype='<U10')

# %%
set(names) #yuqoridagi qiymatlarni qaytaradi
# Out:
# {np.str_('Abdurahmon'), np.str_('Hasan'), np.str_('Sarvar'), np.str_('Temur')}

# %%
# isin ikta massivni elementlarini solishtirib ikkalasida ham qatnashganini True qaytaradi

# %%
arr1 = np.array([6, 0, 0, 3, 2, 5, 6])
arr2 = np.array([0, 2, 3])

# %%
np.isin(arr1, arr2)
# Out:
# array([False,  True,  True,  True,  True, False, False])

# %%
# setdiff1d ikta massiv elementlarini solishtirib birinchi massiv ichidagi elementlardan qaysi biri ikkinchi massivda bo'lmasa shuni qaytaradi

# %%
names1 = np.array(["Kamol", "Abdurahmon", "Hasan", "Muhammad", "Obid", "Temur"])
names2 = np.array(["Sarvar", "Abdurahmon", "Husan", "Temur", "Sarvar", "Temur"])

# %%
np.setdiff1d(names1, names2)
# Out:
# array(['Hasan', 'Kamol', 'Muhammad', 'Obid'], dtype='<U10')
