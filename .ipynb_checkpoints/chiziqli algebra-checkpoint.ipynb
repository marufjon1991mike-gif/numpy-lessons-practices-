# %%
import numpy as np

# %%
x = np.arange(6).reshape(2,3)

# %%
x
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
y = np.arange(6,12).reshape(3,2)

# %%
y
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
x.dot(y) #matritsalarni ko'paytirish
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
y.dot(x)
# Out:
# array([[21, 34, 47],
#        [27, 44, 61],
#        [33, 54, 75]])

# %%
np.dot(x, y) # x ni y ga ko'paytirish
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
np.dot(y, x) #y ni x ga ko'paytirish
# Out:
# array([[21, 34, 47],
#        [27, 44, 61],
#        [33, 54, 75]])
