# %%
import numpy as np

# %%
arr = np.random.rand(4)

# %%
arr
# Out:
# array([0.74224907, 0.28256017, 0.71873921, 0.15705589])

# %%
np.sort(arr) #sonlarni kichigidan kattasiga qarab tartiblaydi
# Out:
# array([0.15705589, 0.28256017, 0.71873921, 0.74224907])

# %%
arr
# Out:
# array([0.15705589, 0.28256017, 0.71873921, 0.74224907])

# %%
rev_arr = -np.sort(-arr) # Katta qiymatda kichigiga qarab tartiblash

# %%
rev_arr
# Out:
# array([0.74224907, 0.71873921, 0.28256017, 0.15705589])

# %%
arr2d = np.random.randn(2,4) # ikki o'lchamli 2 qator 4 ustunli massiv

# %%
arr2d
# Out:
# array([[ 0.54762443,  1.0346322 , -0.03199453,  0.32730969],
#        [-0.98174515, -0.54457853,  1.37111528, -1.43405178]])

# %%
col_srt = np.sort(arr2d, axis = 0) # ustun bo'yicha tartiblash

# %%
col_srt
# Out:
# array([[-0.98174515, -0.54457853, -0.03199453, -1.43405178],
#        [ 0.54762443,  1.0346322 ,  1.37111528,  0.32730969]])

# %%
row_srt = np.sort(arr2d, axis = 1) # qator bo'yicha tartiblash

# %%
row_srt
# Out:
# array([[-0.03199453,  0.32730969,  0.54762443,  1.0346322 ],
#        [-1.43405178, -0.98174515, -0.54457853,  1.37111528]])
